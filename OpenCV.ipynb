# %% [markdown]
# [***LinkedIn***](https://www.linkedin.com/in/haytam-el-youssfi/) [***Twitter***](https://twitter.com/HaytamYoussfi)

# %% [markdown]
# # Getting Started with Images

# %% [markdown]
# ## Using OpenCV

# %% [markdown]
# Use the function ***cv2.imread()*** to read an image. The image should be in the working directory or a full path of image should be given.

# %% [markdown]
# Second argument is a ***flag*** which specifies the way image should be read.
#
# + **cv2.IMREAD_COLOR** : Loads a color image. Any transparency of image will be neglected. It is the default flag.
# + **cv2.IMREAD_GRAYSCALE** : Loads image in grayscale mode
# + **cv2.IMREAD_UNCHANGED** : Loads image as such including alpha channel

# %%
# Read Image 
import numpy as np
import cv2
# Load an color image in grayscale
img = cv2.imread('Img_test.png',0)
print(img) # Even if the image path is wrong, it won’t throw any error, but print img will give you None
# Out:
# [[246 246 246 ... 246 246 246]
#  [246 246 246 ... 246 246 246]
#  [246 246 246 ... 246 246 246]
#  ...
#  [246 246 246 ... 246 246 246]
#  [246 246 246 ... 246 246 246]
#  [246 246 246 ... 246 246 246]]

# %% [markdown]
# ## Display an image

# %% [markdown]
# Utilisez la fonction ***cv2.imshow()*** pour afficher une image dans une fenêtre. La fenêtre s'adapte automatiquement à la taille de l'image.

# %% [markdown]
# First argument is a window name which is a string. second argument is our image. You can create as many windows as you wish, but with different window names

# %%
cv2.imshow('Image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ***cv2.waitKey()*** is a keyboard binding function. Its argument is the time in milliseconds. The function waits for specified milliseconds for any keyboard event. If you press any key in that time, the program continues. If 0 is passed, it waits indefinitely for a key stroke. It can also be set to detect specific key strokes like, if key a is pressed etc which we will discuss below.

# %% [markdown]
# ***cv2.destroyAllWindows()*** simply destroys all the windows we created. If you want to destroy any specific window, use the function cv2.destroyWindow() where you pass the exact window name as the argument.

# %% [markdown]
# ## Write an image

# %% [markdown]
# Use the function ***cv2.imwrite()*** to save an image.

# %% [markdown]
# First argument is the file name, second argument is the image you want to save.

# %%
cv2.imwrite('Img_test.png',img) # This will save the image in PNG format in the working directory.
# Out:
# True

# %%
import numpy as np
import cv2

img = cv2.imread('Img_test.png',0)
cv2.imshow('Window',img)
k = cv2.waitKey(0) & 0xFF

if k == 27:         # wait for ESC key to exit
    
    cv2.destroyAllWindows()
    
elif k == ord('s'): # wait for 's' key to save and exit
    
    cv2.imwrite('Img_test.png',img)
    cv2.destroyAllWindows()

# %% [markdown]
# ## Using Matplotlib

# %%
from matplotlib import pyplot as plt

img = cv2.imread('picture.png',0)
plt.imshow(img, cmap = 'gray')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()
